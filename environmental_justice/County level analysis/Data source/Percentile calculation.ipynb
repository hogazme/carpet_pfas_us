# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/mchen48/Box/01 Research/PFASs/PFASs_in_Carpet/00 PFAS_US_carpet/GIS_analysis/County level analysis/Data source/InUseStock_High_StatusQuo.csv')

# %%
df
# Out:
#       GeoID  StID                County,State  InUseStock1990  InUseStock2020  \
# 0      1001     1     Autauga County, Alabama       50.391325      124.611169
# 1      1003     1     Baldwin County, Alabama      149.382414      523.716109
# 2      1005     1     Barbour County, Alabama       35.272917       51.453116
# 3      1007     1        Bibb County, Alabama       20.099390       40.317942
# 4      1009     1      Blount County, Alabama       51.004414      113.157519
# ...     ...   ...                         ...             ...             ...
# 3137  56037    56  Sweetwater County, Wyoming       57.912667       96.302262
# 3138  56039    56       Teton County, Wyoming       18.358072       57.917378
# 3139  56041    56       Uinta County, Wyoming       28.352699       46.501545
# 3140  56043    56    Washakie County, Wyoming       14.136056       19.839325
# 3141  56045    56      Weston County, Wyoming       10.825587       16.994674
#
#       InUseStock2060
# ...

# %%
df['1990_Percentile']=df['InUseStock1990'].rank(pct=True)
df['2020_Percentile']=df['InUseStock2020'].rank(pct=True)
df['2060_Percentile']=df['InUseStock2060'].rank(pct=True)

# %%
year = 2060

# %%
Percentile_20 = df[df[f'{year}_Percentile']<0.2]
Percentile_40 = df[df[f'{year}_Percentile']<0.4]
Percentile_60 = df[df[f'{year}_Percentile']<0.6]
Percentile_80 = df[df[f'{year}_Percentile']<0.8]
Percentile_90 = df[df[f'{year}_Percentile']<0.9]
Percentile_95 = df[df[f'{year}_Percentile']<0.95]
Percentile_99 = df[df[f'{year}_Percentile']<0.99]

# %%
print(Percentile_20[f'InUseStock{year}'].max(),
      Percentile_40[f'InUseStock{year}'].max(),
      Percentile_60[f'InUseStock{year}'].max(),
      Percentile_80[f'InUseStock{year}'].max(),
      Percentile_90[f'InUseStock{year}'].max(),
      Percentile_95[f'InUseStock{year}'].max(),
      Percentile_99[f'InUseStock{year}'].max(),
      df[f'InUseStock{year}'].max())
# Out:
# 13.63487214 29.21312194 60.44015325 185.3805161 522.5450204 1028.99675 3287.467966 17186.63302

# %%
df = pd.read_csv('C:/Users/mchen48/Box/01 Research/PFASs/PFASs_in_Carpet/00 PFAS_US_carpet/GIS_analysis/County level analysis/Data source/PC_InUseEmiss_High_StatusQuo.csv')

# %%
df
# Out:
#       GeoID  StID                County,State  PCInUseEmiss1990  \
# 0      1001     1     Autauga County, Alabama         25.572284
# 1      1003     1     Baldwin County, Alabama         26.317228
# 2      1005     1     Barbour County, Alabama         24.109847
# 3      1007     1        Bibb County, Alabama         20.985671
# 4      1009     1      Blount County, Alabama         22.526102
# ...     ...   ...                         ...               ...
# 3137  56037    56  Sweetwater County, Wyoming         26.002012
# 3138  56039    56       Teton County, Wyoming         28.400116
# 3139  56041    56       Uinta County, Wyoming         26.504357
# 3140  56043    56    Washakie County, Wyoming         29.457021
# 3141  56045    56      Weston County, Wyoming         29.039112
#
#       PCInUseEmiss2020  PCInUseEmiss2060
# 0            17.523941         17.357658
# 1            18.034429         17.956954
# 2            16.521775         15.806796
# ...

# %%
df['1990_Percentile']=df['PCInUseEmiss1990'].rank(pct=True)
df['2020_Percentile']=df['PCInUseEmiss2020'].rank(pct=True)
df['2060_Percentile']=df['PCInUseEmiss2060'].rank(pct=True)

# %%
df
# Out:
#       GeoID  StID                County,State  PCInUseEmiss1990  \
# 0      1001     1     Autauga County, Alabama         25.572284
# 1      1003     1     Baldwin County, Alabama         26.317228
# 2      1005     1     Barbour County, Alabama         24.109847
# 3      1007     1        Bibb County, Alabama         20.985671
# 4      1009     1      Blount County, Alabama         22.526102
# ...     ...   ...                         ...               ...
# 3137  56037    56  Sweetwater County, Wyoming         26.002012
# 3138  56039    56       Teton County, Wyoming         28.400116
# 3139  56041    56       Uinta County, Wyoming         26.504357
# 3140  56043    56    Washakie County, Wyoming         29.457021
# 3141  56045    56      Weston County, Wyoming         29.039112
#
#       PCInUseEmiss2020  PCInUseEmiss2060  1990_Percentile  2020_Percentile  \
# 0            17.523941         17.357658         0.261617         0.261617
# ...

# %%
year = 2060

# %%
Percentile_20 = df[df[f'{year}_Percentile']<0.2]
Percentile_40 = df[df[f'{year}_Percentile']<0.4]
Percentile_60 = df[df[f'{year}_Percentile']<0.6]
Percentile_80 = df[df[f'{year}_Percentile']<0.8]
Percentile_90 = df[df[f'{year}_Percentile']<0.9]
Percentile_95 = df[df[f'{year}_Percentile']<0.95]
Percentile_99 = df[df[f'{year}_Percentile']<0.99]

# %%
print(Percentile_20[f'PCInUseEmiss{year}'].max(),
      Percentile_40[f'PCInUseEmiss{year}'].max(),
      Percentile_60[f'PCInUseEmiss{year}'].max(),
      Percentile_80[f'PCInUseEmiss{year}'].max(),
      Percentile_90[f'PCInUseEmiss{year}'].max(),
      Percentile_95[f'PCInUseEmiss{year}'].max(),
      Percentile_99[f'PCInUseEmiss{year}'].max(),
      df[f'PCInUseEmiss{year}'].max())
# Out:
# 16.90845496 18.17061708 19.31664254 20.82741246 22.06787589 23.21825446 25.51952332 32.42058464

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 20))
sns.set(style='white', font_scale=1.5)
# sns.set_context('talk')

#dodgerblue
#orangered

sns.boxplot(x='label', y='PEOPCOLORPCT', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[0],legend=False)
sns.boxplot(x='label', y='LOWINCPCT', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[1],legend=False)
sns.boxplot(x='label', y='UNEMPPCT', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[2],legend=False)
sns.boxplot(x='label', y='PM25', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[3],legend=False)
sns.boxplot(x='label', y='DSLPM', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[4],legend=False)
sns.boxplot(x='label', y='RESP', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[5],legend=False)
sns.boxplot(x='label', y='RSEI_AIR', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[6],legend=False)
sns.boxplot(x='label', y='PTRAF', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[7],legend=False)
sns.boxplot(x='label', y='PRE1960PCT', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[8],legend=False)
sns.boxplot(x='label', y='PNPL', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[9],legend=False)
sns.boxplot(x='label', y='PRMP', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[10],legend=False)
sns.boxplot(x='label', y='PWDIS', hue='label', data=df_CT_EJ_InUseStock_High_StatusQuo_2023, showfliers=False,ax=axes[11],legend=False)

# axes[0].set_xticklabels(['20', '40','60','80','100'])
# axes[1].set_xticklabels(['20', '40','60','80','100'])
# axes[2].set_xticklabels(['20', '40','60','80','100'])
# Set custom x-axis tick labels and positions for each subplot
ticks = [0, 1, 2, 3, 4, 5, 6]  # Custom tick locations
axes[0].xaxis.set_major_locator(FixedLocator(range(len(ticks))))  # Set tick locations
axes[0].xaxis.set_major_formatter(FixedFormatter(ticks))  # Set tick labels
axes[1].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[1].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[2].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[2].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[3].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[3].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[4].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[4].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[5].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[5].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[6].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[6].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[7].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[7].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[8].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[8].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[9].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[9].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[10].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[10].xaxis.set_major_formatter(FixedFormatter(ticks))
axes[11].xaxis.set_major_locator(FixedLocator(range(len(ticks))))
axes[11].xaxis.set_major_formatter(FixedFormatter(ticks))

axes[0].set_xlabel('')
axes[1].set_xlabel('')
axes[2].set_xlabel('')
axes[3].set_xlabel('')
axes[4].set_xlabel('')
axes[5].set_xlabel('')
axes[6].set_xlabel('')
axes[7].set_xlabel('')
axes[8].set_xlabel('')
axes[9].set_xlabel('')
axes[10].set_xlabel('')
axes[11].set_xlabel('')


# axes[0].set_ylabel('People of Color (%)',fontsize=16)
# axes[1].set_ylabel('Low Income (%)',fontsize=16)
# axes[2].set_ylabel('Unemployment (%)',fontsize=16)

plt.tight_layout()
# plt.savefig('boxplot.png')
plt.show()
